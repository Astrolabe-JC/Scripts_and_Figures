# %%
# modules import
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from datetime import datetime, timedelta
import seaborn as sns

# %%
# Open Data
#file paths
ref1 = '/Users/jcaillet/Documents/nemo/DATA_OBSERVATIONS/Basal_melting/Data_melting_period.pkl' 
ref_Dotson1 = '/Users/jcaillet/Documents/nemo/DATA_OBSERVATIONS/Basal_melting/Data_melting_Dotson.pkl'
ref_Getz1 = '/Users/jcaillet/Documents/nemo/DATA_OBSERVATIONS/Basal_melting/Data_melting_Getz.pkl'
ref_PineIsland1 = '/Users/jcaillet/Documents/nemo/DATA_OBSERVATIONS/Basal_melting/Data_melting_PineIsland.pkl'
model = '/Users/jcaillet/Documents/nemo/AMUXL025/ANALYSES/COMPLEMENT/NETCDF_MELT_testDOT2.nc'

#open file
ref = pd.read_pickle(ref1)
ref_Dotson = pd.read_pickle(ref_Dotson1)
ref_Getz = pd.read_pickle(ref_Getz1)
ref_PineIsland = pd.read_pickle(ref_PineIsland1)
SBC = xr.open_mfdataset(model)

# %%
sns.set_context('paper')
x = [datetime(1965,1,1,0,0,0), datetime(2019,1,1,0,0,0)] 
# figure
        # Create new plot
fig = plt.figure(figsize = (7.08, 9))

    # Cosgrove
ax5 = fig.add_subplot(611)
num = 2
SBC0 = SBC.melt[4, :, 0]
SBCP = SBC.melt[4, :, 1]
SBCT = SBC.melt[4, :, 2]
ax5.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax5.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax5.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax5.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax5.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax5.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Depoorter 2003-2008'][num] - ref['error_Depoorter 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Depoorter 2003-2008'][num]
ax5.add_patch(Rectangle(xy, w, h, color='yellow', label ='Depoorter 2003-2008', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax5.axes.xaxis.set_ticklabels([]) 
ax5.set_title('a) Cosgrove')
ax5.set_xlim(x[0], x[1])
ax5.set_ylim(0,20)
    
    # Pine Island
ax2 = fig.add_subplot(612)
num = 8
SBC0 = SBC.melt[5, :, 0]
SBCP = SBC.melt[5, :, 1]
SBCT = SBC.melt[5, :, 2]
ax2.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax2.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax2.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax2.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax2.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax2.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Depoorter 2003-2008'][num] - ref['error_Depoorter 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Depoorter 2003-2008'][num]
ax2.add_patch(Rectangle(xy, w, h, color='yellow', label ='Depoorter 2003-2008', alpha = 0.5))
xy = datetime(2008,1,1,0,0,0), ref['melt_Shean 2008-2015'][num] - ref['error_Shean 2008-2015'][num]
w, h = timedelta(days=8 * 365), 2 * ref['error_Shean 2008-2015'][num]
ax2.add_patch(Rectangle(xy, w, h, color='purple', label ='Shean 2008-2015', alpha = 0.5))
xy = datetime(1993,12,1,0,0,0), ref_PineIsland['melt_Dutrieux'][0] - ref_PineIsland['error_Dutrieux'][0]
w, h = timedelta(days=4 *30), 2 * ref_PineIsland['error_Dutrieux'][0]
ax2.add_patch(Rectangle(xy, w, h, color='green', label ='Dutrieux', alpha = 0.5))
xy = datetime(2006,12,1,0,0,0), ref_PineIsland['melt_Dutrieux'][1] - ref_PineIsland['error_Dutrieux'][1]
w, h = timedelta(days=4 *30), 2 * ref_PineIsland['error_Dutrieux'][1]
ax2.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2008,12,1,0,0,0), ref_PineIsland['melt_Dutrieux'][2] - ref_PineIsland['error_Dutrieux'][2]
w, h = timedelta(days=4 *30), 2 * ref_PineIsland['error_Dutrieux'][2]
ax2.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2009,12,1,0,0,0), ref_PineIsland['melt_Dutrieux'][3] - ref_PineIsland['error_Dutrieux'][3]
w, h = timedelta(days=4 *30), 2 * ref_PineIsland['error_Dutrieux'][3]
ax2.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2011,12,1,0,0,0), ref_PineIsland['melt_Dutrieux'][4] - ref_PineIsland['error_Dutrieux'][4]
w, h = timedelta(days=4 *30), 2 * ref_PineIsland['error_Dutrieux'][4]
ax2.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax2.axes.xaxis.set_ticklabels([])
ax2.set_title('b) Pine Island')
ax2.set_xlim(x[0], x[1])
ax2.set_ylim(0,120)
    
        # Thwaites
ax3 = fig.add_subplot(613)
num = 7
SBC0 = SBC.melt[1, :, 0]
SBCP = SBC.melt[1, :, 1]
SBCT = SBC.melt[1, :, 2]
ax3.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax3.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax3.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax3.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax3.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax3.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Depoorter 2003-2008'][num] - ref['error_Depoorter 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Depoorter 2003-2008'][num]
ax3.add_patch(Rectangle(xy, w, h, color='yellow', label ='Depoorter 2003-2008', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax3.axes.xaxis.set_ticklabels([])
ax3.set_title('c) Thwaites')
ax3.set_xlim(x[0], x[1])
ax3.set_ylim(0,110)
    
        # Crosson
ax7 = fig.add_subplot(614)
num = 6
SBC0 = SBC.melt[2, :, 0]
SBCP = SBC.melt[2, :, 1]
SBCT = SBC.melt[2, :, 2]
ax7.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax7.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax7.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax7.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax7.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax7.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax7.axes.xaxis.set_ticklabels([])
ax7.set_title('d) Crosson')
ax7.set_xlim(x[0], x[1])
ax7.set_ylim(0,50)
    
    # Dotson
ax1 = fig.add_subplot(615)
num = 4
SBC0 = SBC.melt[3, :, 0]
SBCP = SBC.melt[3, :, 1]
SBCT = SBC.melt[3, :, 2]
ax1.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax1.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax1.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax1.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax1.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax1.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
xy = datetime(1999,12,1,0,0,0), ref_Dotson['melt_Jenkins'][0] - ref_Dotson['error_Jenkins'][0]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][0]
ax1.add_patch(Rectangle(xy, w, h, color='green', label ='Jenkins', alpha = 0.5))
xy = datetime(2005,12,1,0,0,0), ref_Dotson['melt_Jenkins'][1] - ref_Dotson['error_Jenkins'][1]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][1]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2006,12,1,0,0,0), ref_Dotson['melt_Jenkins'][2] - ref_Dotson['error_Jenkins'][2]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][2]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2008,12,1,0,0,0), ref_Dotson['melt_Jenkins'][3] - ref_Dotson['error_Jenkins'][3]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][3]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2010,12,1,0,0,0), ref_Dotson['melt_Jenkins'][4] - ref_Dotson['error_Jenkins'][4]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][4]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2011,12,1,0,0,0), ref_Dotson['melt_Jenkins'][5] - ref_Dotson['error_Jenkins'][5]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][5]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2013,12,1,0,0,0), ref_Dotson['melt_Jenkins'][6] - ref_Dotson['error_Jenkins'][6]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][6]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
xy = datetime(2015,12,1,0,0,0), ref_Dotson['melt_Jenkins'][7] - ref_Dotson['error_Jenkins'][7]
w, h = timedelta(days=4 *30), 2 * ref_Dotson['error_Jenkins'][7]
ax1.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax1.axes.xaxis.set_ticklabels([])
ax1.set_title('e) Dotson')
ax1.set_xlim(x[0], x[1])
ax1.set_ylim(0,125)

        #Getz
ax = fig.add_subplot(616)
num = 9
        # model
SBC0 = SBC.melt[0, :, 0]
SBCP = SBC.melt[0, :, 1]
SBCT = SBC.melt[0, :, 2]
ax.plot(SBC0.time, SBC0, color= 'black', label = 'REFERENCE')
ax.plot(SBCP.time, SBCP, color= 'silver', label = 'PREC x0.7')
ax.plot(SBCT.time, SBCT, color= 'grey', label = 'TEMP -0.5°C')
        # Adusumilli 1994-2018
xy = datetime(1994,1,1,0,0,0), ref['melt_Adusumilli 1994-2018'][num] - ref['error_Adusumilli 1994-2018'][num]
w, h = timedelta(days=25 * 365), 2 * ref['error_Adusumilli 1994-2018'][num]
ax.add_patch(Rectangle(xy, w, h, color='royalblue', label ='Adusumilli 1994-2018', alpha = 0.7))
        # Adusumilli 2010-2018
xy = datetime(2010,1,1,0,0,0), ref['melt_Adusumilli 2010-2018'][num] - ref['error_Adusumilli 2010-2018'][num]
w, h = timedelta(days=9 * 365), 2 * ref['error_Adusumilli 2010-2018'][num]
ax.add_patch(Rectangle(xy, w, h, color='deepskyblue', label ='Adusumilli 2010-2018', alpha = 0.5))
        # Rignot
xy = datetime(2003,1,1,0,0,0), ref['melt_Rignot 2003-2008'][num] - ref['error_Rignot 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Rignot 2003-2008'][num]
ax.add_patch(Rectangle(xy, w, h, color='red', label ='Rignot 2003-2008', alpha = 0.5))
        # Depoorter
xy = datetime(2003,1,1,0,0,0), ref['melt_Depoorter 2003-2008'][num] - ref['error_Depoorter 2003-2008'][num]
w, h = timedelta(days=6 * 365), 2 * ref['error_Depoorter 2003-2008'][num]
ax.add_patch(Rectangle(xy, w, h, color='yellow', label ='Depoorter 2003-2008', alpha = 0.5))
        # Jacobs
xy = datetime(1999,12,1,0,0,0), ref_Getz['melt_Jacobs'][0] - ref_Getz['error_Jacobs'][0]
w, h = timedelta(days=4 *30), 2 * ref_Getz['error_Jacobs'][0]
ax.add_patch(Rectangle(xy, w, h, color='green', label ='Jacobs', alpha = 0.5))
xy = datetime(2006,12,1,0,0,0), ref_Getz['melt_Jacobs'][1] - ref_Getz['error_Jacobs'][1]
w, h = timedelta(days=4 *30), 2 * ref_Getz['error_Jacobs'][1]
ax.add_patch(Rectangle(xy, w, h, color='green', alpha = 0.5))
plt.legend(loc = 'lower left', prop={"size":5.5})
plt.grid(True)
ax.set_xlabel('Time', fontsize = 10)
ax.set_title('f) Getz')
ax.set_xlim(x[0], x[1])
ax.set_ylim(0,500)
fig.text(0.0, 0.5, 'Mass loss (Gt.y$^{-1}$)', ha='center', va='center', rotation='vertical')  

plt.tight_layout()

fig.savefig('/Users/jcaillet/Documents/nemo/AMUXL025/ANALYSES/RESULTS/montly_melt_obs_corr.pdf', bbox_inches="tight") 
plt.show()
