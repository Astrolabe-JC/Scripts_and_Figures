# %%
# modules import
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
######################################### figure for continental shelf ########################################################
sns.set_context('paper')
# data we used. you need to indicate the path
general_path = '/Users/jcaillet/Documents/nemo/'
comparison_profil_TS_continental_shelf = general_path + 'AMUXL025/REFERENCE/profil_Salinity_Temperature.pdf'  # location to save the figure
mesure1 = general_path + 'DATA_OBSERVATIONS/Vertical_profils/mesure_AMUXL025_L20052018.nc' # files with observation
ref1 = general_path + 'AMUXL025/REFERENCE/REF01/REF01_profils.nc' # case 1 of Nemo result
ref2 = general_path + 'AMUXL025/REFERENCE/REF02_EFR010/REF02_profils.nc' 
ref3 = general_path + 'AMUXL025/REFERENCE/REF03_BDY/REF03_profils.nc' # case 2 of Nemo result
ref4 = general_path + 'AMUXL025/REFERENCE/REF05_HTAU60/REF05_profils.nc'
ref5 = general_path + 'AMUXL025/REFERENCE/REF04_BDY_HTAU60/REF04_profils.nc'
ref6 = general_path + 'AMUXL025/REFERENCE/REF06_GAMMA066/REF06_profils.nc'
ref7 = general_path + 'AMUXL025/REFERENCE/REF07_TOPO_THW/REF07_profils.nc'
ref8 = general_path + 'AMUXL025/REFERENCE/REF08_DFS52/REF08_profils.nc'

# open files
mesure = xr.open_mfdataset(mesure1)
ref1 = xr.open_mfdataset(ref1)
ref2 = xr.open_mfdataset(ref2)
ref3 = xr.open_mfdataset(ref3)
ref4 = xr.open_mfdataset(ref4)
ref5 = xr.open_mfdataset(ref5)
ref6 = xr.open_mfdataset(ref6)
ref7 = xr.open_mfdataset(ref7)
ref8 = xr.open_mfdataset(ref8)

## Modelled data
   
# Temperature profil in front of Pine Island and Thwaites
    # geographic box selection
PineThwaites_T_sel_1 = ref1.T_conservative.where((ref1.longitude > -108) & (ref1.longitude < -100) & (ref1.latitude > -76) & (ref1.latitude < -74))
PineThwaites_T_profil_1 = PineThwaites_T_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
PineThwaites_T_profil_1 = PineThwaites_T_profil_1.to_dataframe()
PineThwaites_T_profil_1 = PineThwaites_T_profil_1.reset_index()
PineThwaites_T_sel_2 = ref2.T_conservative.where((ref2.longitude > -108) & (ref2.longitude < -100) & (ref2.latitude > -76) & (ref2.latitude < -74))
PineThwaites_T_profil_2 = PineThwaites_T_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
PineThwaites_T_profil_2 = PineThwaites_T_profil_2.to_dataframe()
PineThwaites_T_profil_2 = PineThwaites_T_profil_2.reset_index()
PineThwaites_T_sel_3 = ref3.T_conservative.where((ref3.longitude > -108) & (ref3.longitude < -100) & (ref3.latitude > -76) & (ref3.latitude < -74))
PineThwaites_T_profil_3 = PineThwaites_T_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
PineThwaites_T_profil_3 = PineThwaites_T_profil_3.to_dataframe()
PineThwaites_T_profil_3 = PineThwaites_T_profil_3.reset_index() 
PineThwaites_T_sel_4 = ref4.T_conservative.where((ref4.longitude > -108) & (ref4.longitude < -100) & (ref4.latitude > -76) & (ref4.latitude < -74))
PineThwaites_T_profil_4 = PineThwaites_T_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
PineThwaites_T_profil_4 = PineThwaites_T_profil_4.to_dataframe()
PineThwaites_T_profil_4 = PineThwaites_T_profil_4.reset_index() 
PineThwaites_T_sel_5 = ref5.T_conservative.where((ref5.longitude > -108) & (ref5.longitude < -100) & (ref5.latitude > -76) & (ref5.latitude < -74))
PineThwaites_T_profil_5 = PineThwaites_T_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
PineThwaites_T_profil_5 = PineThwaites_T_profil_5.to_dataframe()
PineThwaites_T_profil_5 = PineThwaites_T_profil_5.reset_index() 
PineThwaites_T_sel_6 = ref6.T_conservative.where((ref6.longitude > -108) & (ref6.longitude < -100) & (ref6.latitude > -76) & (ref6.latitude < -74))
PineThwaites_T_profil_6 = PineThwaites_T_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
PineThwaites_T_profil_6 = PineThwaites_T_profil_6.to_dataframe()
PineThwaites_T_profil_6 = PineThwaites_T_profil_6.reset_index() 
PineThwaites_T_sel_7 = ref7.T_conservative.where((ref7.longitude > -108) & (ref7.longitude < -100) & (ref7.latitude > -76) & (ref7.latitude < -74))
PineThwaites_T_profil_7 = PineThwaites_T_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
PineThwaites_T_profil_7 = PineThwaites_T_profil_7.to_dataframe()
PineThwaites_T_profil_7 = PineThwaites_T_profil_7.reset_index() 
PineThwaites_T_sel_8 = ref8.T_conservative.where((ref8.longitude > -108) & (ref8.longitude < -100) & (ref8.latitude > -76) & (ref8.latitude < -74))
PineThwaites_T_profil_8 = PineThwaites_T_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
PineThwaites_T_profil_8 = PineThwaites_T_profil_8.to_dataframe()
PineThwaites_T_profil_8 = PineThwaites_T_profil_8.reset_index() 

# Temperature profil in front of Dotson
    # geographic box selection
Dotson_T_sel_1 = ref1.T_conservative.where((ref1.longitude > -114) & (ref1.longitude < -111) & (ref1.latitude > -75) & (ref1.latitude < -73))
Dotson_T_profil_1 = Dotson_T_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
Dotson_T_profil_1 = Dotson_T_profil_1.to_dataframe()
Dotson_T_profil_1 = Dotson_T_profil_1.reset_index()
Dotson_T_sel_2 = ref2.T_conservative.where((ref2.longitude > -114) & (ref2.longitude < -111) & (ref2.latitude > -75) & (ref2.latitude < -73))
Dotson_T_profil_2 = Dotson_T_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
Dotson_T_profil_2 = Dotson_T_profil_2.to_dataframe()
Dotson_T_profil_2 = Dotson_T_profil_2.reset_index()
Dotson_T_sel_3 = ref3.T_conservative.where((ref3.longitude > -114) & (ref3.longitude < -111) & (ref3.latitude > -75) & (ref3.latitude < -73))
Dotson_T_profil_3 = Dotson_T_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
Dotson_T_profil_3 = Dotson_T_profil_3.to_dataframe()
Dotson_T_profil_3 = Dotson_T_profil_3.reset_index()
Dotson_T_sel_4 = ref4.T_conservative.where((ref4.longitude > -114) & (ref4.longitude < -111) & (ref4.latitude > -75) & (ref4.latitude < -73))
Dotson_T_profil_4 = Dotson_T_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
Dotson_T_profil_4 = Dotson_T_profil_4.to_dataframe()
Dotson_T_profil_4 = Dotson_T_profil_4.reset_index()
Dotson_T_sel_5 = ref5.T_conservative.where((ref5.longitude > -114) & (ref5.longitude < -111) & (ref5.latitude > -75) & (ref5.latitude < -73))
Dotson_T_profil_5 = Dotson_T_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
Dotson_T_profil_5 = Dotson_T_profil_5.to_dataframe()
Dotson_T_profil_5 = Dotson_T_profil_5.reset_index()
Dotson_T_sel_6 = ref6.T_conservative.where((ref6.longitude > -114) & (ref6.longitude < -111) & (ref6.latitude > -75) & (ref6.latitude < -73))
Dotson_T_profil_6 = Dotson_T_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
Dotson_T_profil_6 = Dotson_T_profil_6.to_dataframe()
Dotson_T_profil_6 = Dotson_T_profil_6.reset_index()
Dotson_T_sel_7 = ref7.T_conservative.where((ref7.longitude > -114) & (ref7.longitude < -111) & (ref7.latitude > -75) & (ref7.latitude < -73))
Dotson_T_profil_7 = Dotson_T_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
Dotson_T_profil_7 = Dotson_T_profil_7.to_dataframe()
Dotson_T_profil_7 = Dotson_T_profil_7.reset_index()
Dotson_T_sel_8 = ref8.T_conservative.where((ref8.longitude > -114) & (ref8.longitude < -111) & (ref8.latitude > -75) & (ref8.latitude < -73))
Dotson_T_profil_8 = Dotson_T_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
Dotson_T_profil_8 = Dotson_T_profil_8.to_dataframe()
Dotson_T_profil_8 = Dotson_T_profil_8.reset_index()

# Temperature profil in front of Getz
    # geographic box selection
Getz_T_sel_1 = ref1.T_conservative.where((ref1.longitude > -135) & (ref1.longitude < -114) & (ref1.latitude > -75) & (ref1.latitude < -73))
Getz_T_profil_1 = Getz_T_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
Getz_T_profil_1 = Getz_T_profil_1.to_dataframe()
Getz_T_profil_1 = Getz_T_profil_1.reset_index()
Getz_T_sel_2 = ref2.T_conservative.where((ref2.longitude > -135) & (ref2.longitude < -114) & (ref2.latitude > -75) & (ref2.latitude < -73))
Getz_T_profil_2 = Getz_T_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
Getz_T_profil_2 = Getz_T_profil_2.to_dataframe()
Getz_T_profil_2 = Getz_T_profil_2.reset_index()
Getz_T_sel_3 = ref3.T_conservative.where((ref3.longitude > -135) & (ref3.longitude < -114) & (ref3.latitude > -75) & (ref3.latitude < -73))
Getz_T_profil_3 = Getz_T_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
Getz_T_profil_3 = Getz_T_profil_3.to_dataframe()
Getz_T_profil_3 = Getz_T_profil_3.reset_index()
Getz_T_sel_4 = ref4.T_conservative.where((ref4.longitude > -135) & (ref4.longitude < -115) & (ref4.latitude > -75) & (ref4.latitude < -73))
Getz_T_profil_4 = Getz_T_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
Getz_T_profil_4 = Getz_T_profil_4.to_dataframe()
Getz_T_profil_4 = Getz_T_profil_4.reset_index()
Getz_T_sel_5 = ref5.T_conservative.where((ref5.longitude > -135) & (ref5.longitude < -115) & (ref5.latitude > -75) & (ref5.latitude < -73))
Getz_T_profil_5 = Getz_T_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
Getz_T_profil_5 = Getz_T_profil_5.to_dataframe()
Getz_T_profil_5 = Getz_T_profil_5.reset_index()
Getz_T_sel_6 = ref6.T_conservative.where((ref6.longitude > -135) & (ref6.longitude < -115) & (ref6.latitude > -75) & (ref6.latitude < -73))
Getz_T_profil_6 = Getz_T_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
Getz_T_profil_6 = Getz_T_profil_6.to_dataframe()
Getz_T_profil_6 = Getz_T_profil_6.reset_index()
Getz_T_sel_7 = ref7.T_conservative.where((ref7.longitude > -135) & (ref7.longitude < -115) & (ref7.latitude > -75) & (ref7.latitude < -73))
Getz_T_profil_7 = Getz_T_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
Getz_T_profil_7 = Getz_T_profil_7.to_dataframe()
Getz_T_profil_7 = Getz_T_profil_7.reset_index()
Getz_T_sel_8 = ref8.T_conservative.where((ref8.longitude > -135) & (ref8.longitude < -115) & (ref8.latitude > -75) & (ref8.latitude < -73))
Getz_T_profil_8 = Getz_T_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
Getz_T_profil_8 = Getz_T_profil_8.to_dataframe()
Getz_T_profil_8 = Getz_T_profil_8.reset_index()

# Salinity profil in front of Pine Island and Thwaites
    # geographic box selection
PineThwaites_S_sel_1 = ref1.S_absolute.where((ref1.longitude > -108) & (ref1.longitude < -100) & (ref1.latitude > -76) & (ref1.latitude < -74))
PineThwaites_S_profil_1 = PineThwaites_S_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
PineThwaites_S_profil_1 = PineThwaites_S_profil_1.to_dataframe()
PineThwaites_S_profil_1 = PineThwaites_S_profil_1.reset_index()
PineThwaites_S_sel_2 = ref2.S_absolute.where((ref2.longitude > -108) & (ref2.longitude < -100) & (ref2.latitude > -76) & (ref2.latitude < -74))
PineThwaites_S_profil_2 = PineThwaites_S_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
PineThwaites_S_profil_2 = PineThwaites_S_profil_2.to_dataframe()
PineThwaites_S_profil_2 = PineThwaites_S_profil_2.reset_index()
PineThwaites_S_sel_3 = ref3.S_absolute.where((ref3.longitude > -108) & (ref3.longitude < -100) & (ref3.latitude > -76) & (ref3.latitude < -74))
PineThwaites_S_profil_3 = PineThwaites_S_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
PineThwaites_S_profil_3 = PineThwaites_S_profil_3.to_dataframe()
PineThwaites_S_profil_3 = PineThwaites_S_profil_3.reset_index() 
PineThwaites_S_sel_4 = ref4.S_absolute.where((ref4.longitude > -108) & (ref4.longitude < -100) & (ref4.latitude > -76) & (ref4.latitude < -74))
PineThwaites_S_profil_4 = PineThwaites_S_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
PineThwaites_S_profil_4 = PineThwaites_S_profil_4.to_dataframe()
PineThwaites_S_profil_4 = PineThwaites_S_profil_4.reset_index() 
PineThwaites_S_sel_5 = ref5.S_absolute.where((ref5.longitude > -108) & (ref5.longitude < -100) & (ref5.latitude > -76) & (ref5.latitude < -74))
PineThwaites_S_profil_5 = PineThwaites_S_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
PineThwaites_S_profil_5 = PineThwaites_S_profil_5.to_dataframe()
PineThwaites_S_profil_5 = PineThwaites_S_profil_5.reset_index() 
PineThwaites_S_sel_6 = ref6.S_absolute.where((ref6.longitude > -108) & (ref6.longitude < -100) & (ref6.latitude > -76) & (ref6.latitude < -74))
PineThwaites_S_profil_6 = PineThwaites_S_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
PineThwaites_S_profil_6 = PineThwaites_S_profil_6.to_dataframe()
PineThwaites_S_profil_6 = PineThwaites_S_profil_6.reset_index() 
PineThwaites_S_sel_7 = ref7.S_absolute.where((ref7.longitude > -108) & (ref7.longitude < -100) & (ref7.latitude > -76) & (ref7.latitude < -74))
PineThwaites_S_profil_7 = PineThwaites_S_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
PineThwaites_S_profil_7 = PineThwaites_S_profil_7.to_dataframe()
PineThwaites_S_profil_7 = PineThwaites_S_profil_7.reset_index() 
PineThwaites_S_sel_8 = ref8.S_absolute.where((ref8.longitude > -108) & (ref8.longitude < -100) & (ref8.latitude > -76) & (ref8.latitude < -74))
PineThwaites_S_profil_8 = PineThwaites_S_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
PineThwaites_S_profil_8 = PineThwaites_S_profil_8.to_dataframe()
PineThwaites_S_profil_8 = PineThwaites_S_profil_8.reset_index() 

# Salinity profil in front of Dotson
    # geographic box selection
Dotson_S_sel_1 = ref1.S_absolute.where((ref1.longitude > -114) & (ref1.longitude < -111) & (ref1.latitude > -75) & (ref1.latitude < -73))
Dotson_S_profil_1 = Dotson_S_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
Dotson_S_profil_1 = Dotson_S_profil_1.to_dataframe()
Dotson_S_profil_1 = Dotson_S_profil_1.reset_index()
Dotson_S_sel_2 = ref2.S_absolute.where((ref2.longitude > -114) & (ref2.longitude < -111) & (ref2.latitude > -75) & (ref2.latitude < -73))
Dotson_S_profil_2 = Dotson_S_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
Dotson_S_profil_2 = Dotson_S_profil_2.to_dataframe()
Dotson_S_profil_2 = Dotson_S_profil_2.reset_index()
Dotson_S_sel_3 = ref3.S_absolute.where((ref3.longitude > -114) & (ref3.longitude < -111) & (ref3.latitude > -75) & (ref3.latitude < -73))
Dotson_S_profil_3 = Dotson_S_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
Dotson_S_profil_3 = Dotson_S_profil_3.to_dataframe()
Dotson_S_profil_3 = Dotson_S_profil_3.reset_index()
Dotson_S_sel_4 = ref4.S_absolute.where((ref4.longitude > -114) & (ref4.longitude < -111) & (ref4.latitude > -75) & (ref4.latitude < -73))
Dotson_S_profil_4 = Dotson_S_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
Dotson_S_profil_4 = Dotson_S_profil_4.to_dataframe()
Dotson_S_profil_4 = Dotson_S_profil_4.reset_index()
Dotson_S_sel_5 = ref5.S_absolute.where((ref5.longitude > -114) & (ref5.longitude < -111) & (ref5.latitude > -75) & (ref5.latitude < -73))
Dotson_S_profil_5 = Dotson_S_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
Dotson_S_profil_5 = Dotson_S_profil_5.to_dataframe()
Dotson_S_profil_5 = Dotson_S_profil_5.reset_index()
Dotson_S_sel_6 = ref6.S_absolute.where((ref6.longitude > -114) & (ref6.longitude < -111) & (ref6.latitude > -75) & (ref6.latitude < -73))
Dotson_S_profil_6 = Dotson_S_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
Dotson_S_profil_6 = Dotson_S_profil_6.to_dataframe()
Dotson_S_profil_6 = Dotson_S_profil_6.reset_index()
Dotson_S_sel_7 = ref7.S_absolute.where((ref7.longitude > -114) & (ref7.longitude < -111) & (ref7.latitude > -75) & (ref7.latitude < -73))
Dotson_S_profil_7 = Dotson_S_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
Dotson_S_profil_7 = Dotson_S_profil_7.to_dataframe()
Dotson_S_profil_7 = Dotson_S_profil_7.reset_index()
Dotson_S_sel_8 = ref8.S_absolute.where((ref8.longitude > -114) & (ref8.longitude < -111) & (ref8.latitude > -75) & (ref8.latitude < -73))
Dotson_S_profil_8 = Dotson_S_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
Dotson_S_profil_8 = Dotson_S_profil_8.to_dataframe()
Dotson_S_profil_8 = Dotson_S_profil_8.reset_index()

# Salinity profil in front of Getz
    # geographic box selection
Getz_S_sel_1 = ref1.S_absolute.where((ref1.longitude > -135) & (ref1.longitude < -114) & (ref1.latitude > -75) & (ref1.latitude < -73))
Getz_S_profil_1 = Getz_S_sel_1.where((ref1.mask == 2) & (ref1.S_absolute !=0)).mean("time")
Getz_S_profil_1 = Getz_S_profil_1.to_dataframe()
Getz_S_profil_1 = Getz_S_profil_1.reset_index()
Getz_S_sel_2 = ref2.S_absolute.where((ref2.longitude > -135) & (ref2.longitude < -114) & (ref2.latitude > -75) & (ref2.latitude < -73))
Getz_S_profil_2 = Getz_S_sel_2.where((ref2.mask == 2) & (ref2.S_absolute !=0)).mean("time")
Getz_S_profil_2 = Getz_S_profil_2.to_dataframe()
Getz_S_profil_2 = Getz_S_profil_2.reset_index()
Getz_S_sel_3 = ref3.S_absolute.where((ref3.longitude > -135) & (ref3.longitude < -114) & (ref3.latitude > -75) & (ref3.latitude < -73))
Getz_S_profil_3 = Getz_S_sel_3.where((ref3.mask == 2) & (ref3.S_absolute !=0)).mean("time")
Getz_S_profil_3 = Getz_S_profil_3.to_dataframe()
Getz_S_profil_3 = Getz_S_profil_3.reset_index()
Getz_S_sel_4 = ref4.S_absolute.where((ref4.longitude > -135) & (ref4.longitude < -115) & (ref4.latitude > -75) & (ref4.latitude < -73))
Getz_S_profil_4 = Getz_S_sel_4.where((ref4.mask == 2) & (ref4.S_absolute !=0)).mean("time")
Getz_S_profil_4 = Getz_S_profil_4.to_dataframe()
Getz_S_profil_4 = Getz_S_profil_4.reset_index()
Getz_S_sel_5 = ref5.S_absolute.where((ref5.longitude > -135) & (ref5.longitude < -115) & (ref5.latitude > -75) & (ref5.latitude < -73))
Getz_S_profil_5 = Getz_S_sel_5.where((ref5.mask == 2) & (ref5.S_absolute !=0)).mean("time")
Getz_S_profil_5 = Getz_S_profil_5.to_dataframe()
Getz_S_profil_5 = Getz_S_profil_5.reset_index()
Getz_S_sel_6 = ref6.S_absolute.where((ref6.longitude > -135) & (ref6.longitude < -115) & (ref6.latitude > -75) & (ref6.latitude < -73))
Getz_S_profil_6 = Getz_S_sel_6.where((ref6.mask == 2) & (ref6.S_absolute !=0)).mean("time")
Getz_S_profil_6 = Getz_S_profil_6.to_dataframe()
Getz_S_profil_6 = Getz_S_profil_6.reset_index()
Getz_S_sel_7 = ref7.S_absolute.where((ref7.longitude > -135) & (ref7.longitude < -115) & (ref7.latitude > -75) & (ref7.latitude < -73))
Getz_S_profil_7 = Getz_S_sel_7.where((ref7.mask == 2) & (ref7.S_absolute !=0)).mean("time")
Getz_S_profil_7 = Getz_S_profil_7.to_dataframe()
Getz_S_profil_7 = Getz_S_profil_7.reset_index()
Getz_S_sel_8 = ref8.S_absolute.where((ref8.longitude > -135) & (ref8.longitude < -115) & (ref8.latitude > -75) & (ref8.latitude < -73))
Getz_S_profil_8 = Getz_S_sel_8.where((ref8.mask == 2) & (ref8.S_absolute !=0)).mean("time")
Getz_S_profil_8 = Getz_S_profil_8.to_dataframe()
Getz_S_profil_8 = Getz_S_profil_8.reset_index()

## observation data           

# Temperature profil in front of Pine Island and Thwaites
    # geographic box selection
        # mean profil
PineThwaites_T_obs_profil = mesure.T_conservative.where((mesure.longitude > -108) & (mesure.longitude < -100) & (mesure.latitude > -76) & (mesure.latitude < -74) & (ref1.mask == 2)).mean('time')
PineThwaites_T_obs_profil = PineThwaites_T_obs_profil.to_dataframe()
PineThwaites_T_obs_profil = PineThwaites_T_obs_profil.reset_index()
        # standard deviation
PineThwaites_T_obs_std = mesure.T_conservative.where((mesure.longitude > -108) & (mesure.longitude < -100) & (mesure.latitude > -76) & (mesure.latitude < -74) & (ref1.mask == 2)).std('time')
PineThwaites_T_obs_std = PineThwaites_T_obs_std.to_dataframe()  

# Temperature profil in front of Dotson
    # geographic box selection
        # mean profil
Dotson_T_obs_profil = mesure.T_conservative.where((mesure.longitude > -114) & (mesure.longitude < -111) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).mean('time')
Dotson_T_obs_profil = Dotson_T_obs_profil.to_dataframe()
Dotson_T_obs_profil = Dotson_T_obs_profil.reset_index()
        # standard deviation
Dotson_T_obs_std = mesure.T_conservative.where((mesure.longitude > -114) & (mesure.longitude < -111) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).std('time')
Dotson_T_obs_std = Dotson_T_obs_std.to_dataframe()

# Temperature profil in front of Getz
    # geographic box selection
        # mean profil
Getz_T_obs_profil = mesure.T_conservative.where((mesure.longitude > -135) & (mesure.longitude < -114) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).mean('time')
Getz_T_obs_profil = Getz_T_obs_profil.to_dataframe()
Getz_T_obs_profil = Getz_T_obs_profil.reset_index()
        # standard deviation
Getz_T_obs_std = mesure.T_conservative.where((mesure.longitude > -135) & (mesure.longitude < -114) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).std('time')
Getz_T_obs_std = Getz_T_obs_std.to_dataframe()
  
    
## std 
PineThwaites_T_obs_std.reset_index(inplace=True)
Dotson_T_obs_std.reset_index(inplace=True)
Getz_T_obs_std.reset_index(inplace=True)
PineThwaites_T_obs_profil = PineThwaites_T_obs_profil.assign(stdm=lambda x: PineThwaites_T_obs_profil.T_conservative - PineThwaites_T_obs_std.T_conservative)
PineThwaites_T_obs_profil = PineThwaites_T_obs_profil.assign(stdp=lambda x: PineThwaites_T_obs_profil.T_conservative + PineThwaites_T_obs_std.T_conservative)
Dotson_T_obs_profil = Dotson_T_obs_profil.assign(stdm=lambda x: Dotson_T_obs_profil.T_conservative - Dotson_T_obs_std.T_conservative)
Dotson_T_obs_profil = Dotson_T_obs_profil.assign(stdp=lambda x: Dotson_T_obs_profil.T_conservative + Dotson_T_obs_std.T_conservative)
Getz_T_obs_profil = Getz_T_obs_profil.assign(stdm=lambda x: Getz_T_obs_profil.T_conservative - Getz_T_obs_std.T_conservative)
Getz_T_obs_profil = Getz_T_obs_profil.assign(stdp=lambda x: Getz_T_obs_profil.T_conservative + Getz_T_obs_std.T_conservative)


## observation data           
# Salinity profil in deep ocean
    # mean profil    
deep_S_profil_obs = mesure.S_absolute.where(ref1.mask == 0).mean('time')
deep_S_profil_obs = deep_S_profil_obs.to_dataframe()
deep_S_profil_obs = deep_S_profil_obs.reset_index()
    # standard deviation
deep_S_std_obs = mesure.S_absolute.where(ref1.mask == 0).std('time')
deep_S_std_obs = deep_S_std_obs.to_dataframe()
      

# Salinity profil in front of Pine Island and Thwaites
    # geographic box selection
        # mean profil
PineThwaites_S_obs_profil = mesure.S_absolute.where((mesure.longitude > -108) & (mesure.longitude < -100) & (mesure.latitude > -76) & (mesure.latitude < -74) & (ref1.mask == 2)).mean('time')
PineThwaites_S_obs_profil = PineThwaites_S_obs_profil.to_dataframe()
PineThwaites_S_obs_profil = PineThwaites_S_obs_profil.reset_index()
        # standard deviation
PineThwaites_S_obs_std = mesure.S_absolute.where((mesure.longitude > -108) & (mesure.longitude < -100) & (mesure.latitude > -76) & (mesure.latitude < -74) & (ref1.mask == 2)).std('time')
PineThwaites_S_obs_std = PineThwaites_S_obs_std.to_dataframe()  

# Salinity profil in front of Dotson
    # geographic box selection
        # mean profil
Dotson_S_obs_profil = mesure.S_absolute.where((mesure.longitude > -114) & (mesure.longitude < -111) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).mean('time')
Dotson_S_obs_profil = Dotson_S_obs_profil.to_dataframe()
Dotson_S_obs_profil = Dotson_S_obs_profil.reset_index()
        # standard deviation
Dotson_S_obs_std = mesure.S_absolute.where((mesure.longitude > -114) & (mesure.longitude < -111) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).std('time')
Dotson_S_obs_std = Dotson_S_obs_std.to_dataframe()

# Salinity profil in front of Getz
    # geographic box selection
        # mean profil
Getz_S_obs_profil = mesure.S_absolute.where((mesure.longitude > -135) & (mesure.longitude < -114) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).mean('time')
Getz_S_obs_profil = Getz_S_obs_profil.to_dataframe()
Getz_S_obs_profil = Getz_S_obs_profil.reset_index()
        # standard deviation
Getz_S_obs_std = mesure.S_absolute.where((mesure.longitude > -135) & (mesure.longitude < -114) & (mesure.latitude > -75) & (mesure.latitude < -73) & (ref1.mask == 2)).std('time')
Getz_S_obs_std = Getz_S_obs_std.to_dataframe()
  
    
## std 
PineThwaites_S_obs_std.reset_index(inplace=True)
Dotson_S_obs_std.reset_index(inplace=True)
Getz_S_obs_std.reset_index(inplace=True)
PineThwaites_S_obs_profil = PineThwaites_S_obs_profil.assign(stdm=lambda x: PineThwaites_S_obs_profil.S_absolute - PineThwaites_S_obs_std.S_absolute)
PineThwaites_S_obs_profil = PineThwaites_S_obs_profil.assign(stdp=lambda x: PineThwaites_S_obs_profil.S_absolute + PineThwaites_S_obs_std.S_absolute)
Dotson_S_obs_profil = Dotson_S_obs_profil.assign(stdm=lambda x: Dotson_S_obs_profil.S_absolute - Dotson_S_obs_std.S_absolute)
Dotson_S_obs_profil = Dotson_S_obs_profil.assign(stdp=lambda x: Dotson_S_obs_profil.S_absolute + Dotson_S_obs_std.S_absolute)
Getz_S_obs_profil = Getz_S_obs_profil.assign(stdm=lambda x: Getz_S_obs_profil.S_absolute - Getz_S_obs_std.S_absolute)
Getz_S_obs_profil = Getz_S_obs_profil.assign(stdp=lambda x: Getz_S_obs_profil.S_absolute + Getz_S_obs_std.S_absolute)



## figure
fig20 =  plt.figure(figsize = (7.08, 5.5)) 

# plot for Pine Island   
    # plot for Temperature
ax1 = plt.subplot(231) # create the first subplot
ax1.plot(PineThwaites_T_obs_profil.T_conservative, PineThwaites_T_obs_profil.depth, color = 'black', linewidth = 1.5, zorder=10)
ax1.fill_betweenx(PineThwaites_T_obs_profil.depth, PineThwaites_T_obs_profil.stdm, PineThwaites_T_obs_profil.stdp,  color = 'black', alpha=0.15)
ax1.plot(PineThwaites_T_profil_1.T_conservative, PineThwaites_T_profil_1.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_2.T_conservative, PineThwaites_T_profil_2.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_3.T_conservative, PineThwaites_T_profil_3.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_4.T_conservative, PineThwaites_T_profil_4.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_5.T_conservative, PineThwaites_T_profil_5.depth, linewidth = 1.5, zorder=9)
ax1.plot(PineThwaites_T_profil_6.T_conservative, PineThwaites_T_profil_6.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_7.T_conservative, PineThwaites_T_profil_7.depth, linewidth = 0.75)
ax1.plot(PineThwaites_T_profil_8.T_conservative, PineThwaites_T_profil_8.depth, linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax1.set_ylabel("Depth (m)", fontsize = 10)
ax1.set_title('Pine Island and Thwaites', fontsize = 10)
ax1.set_ylim(0, 1200)
ax1.set_xlim(-2, 2)
plt.grid(True)
plt.gca().invert_yaxis()

# Plot for Dotson
ax2 = plt.subplot(232) # create the first subplot
ax2.plot(Dotson_T_obs_profil.T_conservative, Dotson_T_obs_profil.depth, color = 'black', linewidth = 1.5, zorder=10)
ax2.fill_betweenx(Dotson_T_obs_profil.depth, Dotson_T_obs_profil.stdm, Dotson_T_obs_profil.stdp,  color = 'black', alpha=0.15)
ax2.plot(Dotson_T_profil_1.T_conservative, Dotson_T_profil_1.depth,  linewidth = 0.75)
ax2.plot(Dotson_T_profil_2.T_conservative, Dotson_T_profil_2.depth,  linewidth = 0.75)
ax2.plot(Dotson_T_profil_3.T_conservative, Dotson_T_profil_3.depth,   linewidth = 0.75)
ax2.plot(Dotson_T_profil_4.T_conservative, Dotson_T_profil_4.depth,  linewidth = 0.75)
ax2.plot(Dotson_T_profil_5.T_conservative, Dotson_T_profil_5.depth,   linewidth = 1.5, zorder=9)
ax2.plot(Dotson_T_profil_6.T_conservative, Dotson_T_profil_6.depth,  linewidth = 0.75)
ax2.plot(Dotson_T_profil_7.T_conservative, Dotson_T_profil_7.depth,   linewidth = 0.75)
ax2.plot(Dotson_T_profil_8.T_conservative, Dotson_T_profil_8.depth,   linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax2.set_xlabel("Conservative Temperature (°C)", fontsize = 10)
ax2.set_title('Dotson', fontsize = 10)
ax2.axes.yaxis.set_ticklabels([]) 
ax2.set_xlim(-2, 2)
ax2.set_ylim(0, 1200)

plt.grid(True)
plt.gca().invert_yaxis()
# Plot for Getz
ax3 = plt.subplot(233) # create the first subplot
ax3.plot(Getz_T_obs_profil.T_conservative, Getz_T_obs_profil.depth, color = 'black', label = 'obs - CTD profil', linewidth = 1.5, zorder=10)
ax3.fill_betweenx(Getz_T_obs_profil.depth, Getz_T_obs_profil.stdm, Getz_T_obs_profil.stdp,  color = 'black', alpha=0.15)
ax3.plot(Getz_T_profil_1.T_conservative, Getz_T_profil_1.depth, label = 'INITIAL', linewidth = 0.75)
ax3.plot(Getz_T_profil_2.T_conservative, Getz_T_profil_2.depth, label = 'EFR', linewidth = 0.75)
ax3.plot(Getz_T_profil_3.T_conservative, Getz_T_profil_3.depth, label = 'BDY', linewidth = 0.75)
ax3.plot(Getz_T_profil_4.T_conservative, Getz_T_profil_4.depth, label = 'HTAU', linewidth = 0.75)
ax3.plot(Getz_T_profil_5.T_conservative, Getz_T_profil_5.depth, label = 'BDY + HTAU', linewidth = 1.5, zorder=9)
ax3.plot(Getz_T_profil_6.T_conservative, Getz_T_profil_6.depth, label = 'BDY + HTAU + GAMMA', linewidth = 0.75)
ax3.plot(Getz_T_profil_7.T_conservative, Getz_T_profil_7.depth, label = 'BDY + HTAU + GAMMA + TOPO', linewidth = 0.75)
ax3.plot(Getz_T_profil_8.T_conservative, Getz_T_profil_8.depth, label = 'BDY + HTAU + FORCING', linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax3.set_title('Getz', fontsize = 10)
ax3.axes.yaxis.set_ticklabels([]) 
ax3.set_xlim(-2, 2)
ax3.set_ylim(0, 1200)
plt.grid(True)
plt.gca().invert_yaxis()


ax4 = plt.subplot(234) # create the first subplot
ax4.plot(PineThwaites_S_obs_profil.S_absolute, PineThwaites_S_obs_profil.depth, color = 'black', linewidth = 1.5, zorder=10)
ax4.fill_betweenx(PineThwaites_S_obs_profil.depth, PineThwaites_S_obs_profil.stdm, PineThwaites_S_obs_profil.stdp,  color = 'black', alpha=0.15)
ax4.plot(PineThwaites_S_profil_1.S_absolute, PineThwaites_S_profil_1.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_2.S_absolute, PineThwaites_S_profil_2.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_3.S_absolute, PineThwaites_S_profil_3.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_4.S_absolute, PineThwaites_S_profil_4.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_5.S_absolute, PineThwaites_S_profil_5.depth, linewidth = 1.5, zorder=9)
ax4.plot(PineThwaites_S_profil_6.S_absolute, PineThwaites_S_profil_6.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_7.S_absolute, PineThwaites_S_profil_7.depth, linewidth = 0.75)
ax4.plot(PineThwaites_S_profil_8.S_absolute, PineThwaites_S_profil_8.depth, linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
#ax4.set_title('Pine Island and Thwaites', fontsize = 10)
ax4.set_ylabel("Depth (m)", fontsize = 10)
ax4.set_ylim(0, 1200)
ax4.set_xlim(33.5, 35)
plt.grid(True)
plt.gca().invert_yaxis()

# Plot for Dotson
ax5 = plt.subplot(235) # create the first subplot
ax5.plot(Dotson_S_obs_profil.S_absolute, Dotson_S_obs_profil.depth, color = 'black', linewidth = 1.5, zorder=10)
ax5.fill_betweenx(Dotson_S_obs_profil.depth, Dotson_S_obs_profil.stdm, Dotson_S_obs_profil.stdp,  color = 'black', alpha=0.15)
ax5.plot(Dotson_S_profil_1.S_absolute, Dotson_S_profil_1.depth,  linewidth = 0.75)
ax5.plot(Dotson_S_profil_2.S_absolute, Dotson_S_profil_2.depth,  linewidth = 0.75)
ax5.plot(Dotson_S_profil_3.S_absolute, Dotson_S_profil_3.depth,   linewidth = 0.75)
ax5.plot(Dotson_S_profil_4.S_absolute, Dotson_S_profil_4.depth,  linewidth = 0.75)
ax5.plot(Dotson_S_profil_5.S_absolute, Dotson_S_profil_5.depth,   linewidth = 1.5, zorder=9)
ax5.plot(Dotson_S_profil_6.S_absolute, Dotson_S_profil_6.depth,  linewidth = 0.75)
ax5.plot(Dotson_S_profil_7.S_absolute, Dotson_S_profil_7.depth,   linewidth = 0.75)
ax5.plot(Dotson_S_profil_8.S_absolute, Dotson_S_profil_8.depth,   linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
ax5.set_xlabel("Absolute salinity (g.kg$^{-1}$)", fontsize = 10)
#ax5.set_title('Dotson', fontsize = 10)
ax5.axes.yaxis.set_ticklabels([]) 
ax5.set_xlim(33.5, 35)
ax5.set_ylim(0, 1200)
plt.grid(True)
plt.gca().invert_yaxis()

# Plot for Getz
ax6 = plt.subplot(236) # create the first subplot
ax6.plot(Getz_S_obs_profil.S_absolute, Getz_S_obs_profil.depth, color = 'black', linewidth = 1.5, zorder=10)
ax6.fill_betweenx(Getz_S_obs_profil.depth, Getz_S_obs_profil.stdm, Getz_S_obs_profil.stdp,  color = 'black', alpha=0.15)
ax6.plot(Getz_S_profil_1.S_absolute, Getz_S_profil_1.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_2.S_absolute, Getz_S_profil_2.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_3.S_absolute, Getz_S_profil_3.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_4.S_absolute, Getz_S_profil_4.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_5.S_absolute, Getz_S_profil_5.depth, linewidth = 1.5, zorder=9)
ax6.plot(Getz_S_profil_6.S_absolute, Getz_S_profil_6.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_7.S_absolute, Getz_S_profil_7.depth, linewidth = 0.75)
ax6.plot(Getz_S_profil_8.S_absolute, Getz_S_profil_8.depth, linewidth = 0.75)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
#ax6.set_title('Getz', fontsize = 10)
ax6.axes.yaxis.set_ticklabels([]) 
ax6.set_xlim(33.5, 35)
ax6.set_ylim(0, 1200)
plt.grid(True)
plt.gca().invert_yaxis()


fig20.legend(bbox_to_anchor=(0.965, 0.03),  ncol=3, fontsize = 10)
#loc="right",
fig20.tight_layout()
fig20.savefig(comparison_profil_TS_continental_shelf, bbox_inches="tight")   
    
plt.show()
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /opt/miniconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ...
